# %%
import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# load in the Playground Equipment data file
data = pd.read_csv("https://pghgishub-pittsburghpa.opendata.arcgis.com/datasets/3ca13246362540fa8b4b567f84a1255b_0.csv?outSR=%7B%22latestWkid%22%3A6565%2C%22wkid%22%3A103142%7D")

# look at the first ten rows of the data
data.head(10)
# Out:
#    OBJECTID  FID_BlockG  STATEFP10  COUNTYFP10  TRACTCE10  BLKGRPCE10  \
# 0         1           0         42           3      40500           1
# 1         2           1         42           3      40400           1
# 2         3           2         42           3      40200           2
# 3         4           3         42           3      30500           2
# 4         5           5         42           3      20300           1
# 5         6           6         42           3      20100           4
# 6         7           7         42           3     262000           1
# 7         8           8         42           3     261500           1
# 8         9          10         42           3     261200           1
# 9        10          11         42           3     260900           1
#
#         GEOID10     NAMELSAD10 MTFCC10 FUNCSTAT10  ...  \
# 0  420030405001  Block Group 1   G5030          S  ...
# 1  420030404001  Block Group 1   G5030          S  ...
# ...
